# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %% [markdown]
# # Fake Dataset
#
# Here is a simple code to generate a fake dataset.

# %%
def linear_regression_dataset():
    # --- Fake dataset ---

    np.random.seed(0)

    ntrain = 1000
    nvalid = 100
    ntest = 100

    # number of features
    nc = 4
    # number of outputs
    no = 2

    A = np.random.randn(nc, no)
    b = np.random.randn(no)

    print("True A\n", A)
    print("True b\n", b)

    def generate_one_dataset(A, b, n):
        nc, no = A.shape
        X = np.random.randn(n, nc)
        Y = X.dot(A)+b
        return np.array(X, dtype='float32'), np.array(Y, dtype='float32')

    Xtrain, Ytrain = generate_one_dataset(A, b, ntrain)
    Xvalid, Yvalid = generate_one_dataset(A, b, nvalid)
    Xtest, Ytest = generate_one_dataset(A, b, ntest)

    return (Xtrain, Ytrain), (Xvalid, Yvalid), (Xtest, Ytest)

# %% [markdown]
# # Linear Regression
#
# Observe and run the following code.
# It performs a linear regression over the artificial dataset.

# %%
class LinearRegression(tf.Module):
    def __init__(self, nc, no, name=None):
        super().__init__(name=name)
        # Linear regression parameters
        self.A = tf.Variable(tf.zeros([nc, no]))
        self.b = tf.Variable(tf.zeros([no]))

    @tf.function
    def __call__(self,x):
        return tf.matmul(x, self.A) + self.b


def linear_regression_v1(trainset, validset, testset):

    Xtrain, Ytrain = trainset
    Xvalid, Yvalid = validset
    Xtest, Ytest = testset
    
    # Hyperparameters
    learning_rate = 5e-2
    training_epochs = 100

    # Xtrain (nxtrain,nc)
    nxtrain, nc = Xtrain.shape
    nxtest, _ = Xtest.shape
    # Ytrain (nxtrain,no)
    no = Ytrain.shape[1]

    module = LinearRegression(nc,no)
    
    # We will use the mean square error as loss
    def loss(target,pred):
        return tf.math.reduce_mean(tf.math.squared_difference(target, pred))
        
    # We will use the mean absolute error as metric
    def metric(target,pred):
        return tf.math.reduce_mean(tf.math.abs(target-pred))
    
    # Beware loss and metric are different think.
    # Loss is the differentiable function used for training
    # Metric is a possibly a non-differentiable function use to measure the accuracy.
    
    # NEW ! Optimizer based on gradient descent
    # It computes gradients of loss over var_list items
    # and construct the updates for var_list items.
    # We don't have to write the gradient step by ourselves
    optimizer = tf.optimizers.SGD(learning_rate=learning_rate)

    # We cycle on epochs
    for epoch in range(training_epochs):
        with tf.GradientTape() as tape:
            trainpred = module(Xtrain)
            trainloss = loss(Ytrain,trainpred)
        grads = tape.gradient(trainloss,module.trainable_variables)
        trainmetric = metric(Ytrain,trainpred)
        
        validpred = module(Xvalid)
        validmetric = metric(Yvalid,validpred)
        
        # NEW ! Optimizer based on gradient descent
        # We let the optimizer do the gradient descent
        optimizer.apply_gradients(zip(grads, module.trainable_variables))
        
        print("Epoch %03d\t train loss %f\t train metric %f\t valid metric %f" %
                  (epoch, trainloss.numpy(), trainmetric.numpy(), validmetric.numpy()))

    testpred = module(Xtest)
    testmetric = metric(Ytest,testpred)
    print("Test metric %f"%(testmetric.numpy(),))
        
    # Found parameters
    print("Estimated A\n", module.A.numpy())
    print('Estimated b\n', module.b.numpy())

linear_regression_v1(*linear_regression_dataset())
# Out:
# True A
#  [[ 1.76405235  0.40015721]
#  [ 0.97873798  2.2408932 ]
#  [ 1.86755799 -0.97727788]
#  [ 0.95008842 -0.15135721]]
# True b
#  [-0.10321885  0.4105985 ]
# Metal device set to: Apple M1
# 2021-09-23 11:22:42.834224: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-09-23 11:22:42.834369: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-09-23 11:22:42.928712: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-09-23 11:22:42.929147: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-09-23 11:22:42.929279: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-09-23 11:22:43.170204: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2021-09-23 11:22:43.248889: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-09-23 11:22:43.457109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 000	 train loss 7.184082	 train metric 2.142293	 valid metric 2.241359
# Epoch 001	 train loss 6.501032	 train metric 2.037724	 valid metric 2.131973
# Epoch 002	 train loss 5.883164	 train metric 1.938288	 valid metric 2.028012
# Epoch 003	 train loss 5.324233	 train metric 1.843725	 valid metric 1.929139
# Epoch 004	 train loss 4.818598	 train metric 1.753836	 valid metric 1.835133
# Epoch 005	 train loss 4.361157	 train metric 1.668375	 valid metric 1.745760
# Epoch 006	 train loss 3.947302	 train metric 1.587111	 valid metric 1.660756
# Epoch 007	 train loss 3.572863	 train metric 1.509852	 valid metric 1.579916
# Epoch 008	 train loss 3.234073	 train metric 1.436387	 valid metric 1.503120
# Epoch 009	 train loss 2.927526	 train metric 1.366513	 valid metric 1.430090
# Epoch 010	 train loss 2.650141	 train metric 1.300064	 valid metric 1.360712
# Epoch 011	 train loss 2.399136	 train metric 1.236870	 valid metric 1.294730
# Epoch 012	 train loss 2.171991	 train metric 1.176772	 valid metric 1.231959
# Epoch 013	 train loss 1.966431	 train metric 1.119623	 valid metric 1.172243
# Epoch 014	 train loss 1.780396	 train metric 1.065277	 valid metric 1.115433
# Epoch 015	 train loss 1.612025	 train metric 1.013589	 valid metric 1.061404
# Epoch 016	 train loss 1.459636	 train metric 0.964423	 valid metric 1.010026
# Epoch 017	 train loss 1.321705	 train metric 0.917653	 valid metric 0.961144
# Epoch 018	 train loss 1.196856	 train metric 0.873166	 valid metric 0.914636
# Epoch 019	 train loss 1.083843	 train metric 0.830860	 valid metric 0.870387
# Epoch 020	 train loss 0.981541	 train metric 0.790628	 valid metric 0.828287
# Epoch 021	 train loss 0.888930	 train metric 0.752366	 valid metric 0.788231
# Epoch 022	 train loss 0.805089	 train metric 0.715965	 valid metric 0.750118
# Epoch 023	 train loss 0.729184	 train metric 0.681333	 valid metric 0.713856
# Epoch 024	 train loss 0.660462	 train metric 0.648386	 valid metric 0.679353
# Epoch 025	 train loss 0.598241	 train metric 0.617041	 valid metric 0.646523
# Epoch 026	 train loss 0.541902	 train metric 0.587228	 valid metric 0.615286
# Epoch 027	 train loss 0.490889	 train metric 0.558871	 valid metric 0.585564
# Epoch 028	 train loss 0.444695	 train metric 0.531901	 valid metric 0.557282
# Epoch 029	 train loss 0.402864	 train metric 0.506242	 valid metric 0.530372
# Epoch 030	 train loss 0.364982	 train metric 0.481828	 valid metric 0.504766
# Epoch 031	 train loss 0.330675	 train metric 0.458598	 valid metric 0.480400
# Epoch 032	 train loss 0.299605	 train metric 0.436499	 valid metric 0.457215
# Epoch 033	 train loss 0.271465	 train metric 0.415472	 valid metric 0.435167
# Epoch 034	 train loss 0.245977	 train metric 0.395464	 valid metric 0.414212
# Epoch 035	 train loss 0.222891	 train metric 0.376425	 valid metric 0.394281
# Epoch 036	 train loss 0.201979	 train metric 0.358310	 valid metric 0.375327
# Epoch 037	 train loss 0.183037	 train metric 0.341071	 valid metric 0.357287
# Epoch 038	 train loss 0.165877	 train metric 0.324665	 valid metric 0.340117
# Epoch 039	 train loss 0.150332	 train metric 0.309054	 valid metric 0.323775
# Epoch 040	 train loss 0.136249	 train metric 0.294197	 valid metric 0.308222
# Epoch 041	 train loss 0.123490	 train metric 0.280058	 valid metric 0.293418
# Epoch 042	 train loss 0.111930	 train metric 0.266602	 valid metric 0.279328
# Epoch 043	 train loss 0.101456	 train metric 0.253797	 valid metric 0.265918
# Epoch 044	 train loss 0.091966	 train metric 0.241610	 valid metric 0.253161
# Epoch 045	 train loss 0.083366	 train metric 0.230012	 valid metric 0.241019
# Epoch 046	 train loss 0.075574	 train metric 0.218975	 valid metric 0.229461
# Epoch 047	 train loss 0.068512	 train metric 0.208471	 valid metric 0.218459
# Epoch 048	 train loss 0.062113	 train metric 0.198473	 valid metric 0.207997
# Epoch 049	 train loss 0.056314	 train metric 0.188958	 valid metric 0.198040
# Epoch 050	 train loss 0.051057	 train metric 0.179901	 valid metric 0.188565
# Epoch 051	 train loss 0.046294	 train metric 0.171279	 valid metric 0.179544
# Epoch 052	 train loss 0.041976	 train metric 0.163074	 valid metric 0.170957
# Epoch 053	 train loss 0.038062	 train metric 0.155265	 valid metric 0.162781
# Epoch 054	 train loss 0.034515	 train metric 0.147833	 valid metric 0.154998
# Epoch 055	 train loss 0.031299	 train metric 0.140758	 valid metric 0.147588
# Epoch 056	 train loss 0.028384	 train metric 0.134025	 valid metric 0.140534
# Epoch 057	 train loss 0.025742	 train metric 0.127616	 valid metric 0.133820
# Epoch 058	 train loss 0.023346	 train metric 0.121516	 valid metric 0.127430
# Epoch 059	 train loss 0.021174	 train metric 0.115710	 valid metric 0.121346
# Epoch 060	 train loss 0.019205	 train metric 0.110184	 valid metric 0.115554
# Epoch 061	 train loss 0.017419	 train metric 0.104924	 valid metric 0.110039
# Epoch 062	 train loss 0.015800	 train metric 0.099916	 valid metric 0.104788
# Epoch 063	 train loss 0.014332	 train metric 0.095149	 valid metric 0.099789
# Epoch 064	 train loss 0.013001	 train metric 0.090611	 valid metric 0.095029
# Epoch 065	 train loss 0.011794	 train metric 0.086291	 valid metric 0.090497
# Epoch 066	 train loss 0.010700	 train metric 0.082179	 valid metric 0.086184
# Epoch 067	 train loss 0.009707	 train metric 0.078263	 valid metric 0.082079
# Epoch 068	 train loss 0.008807	 train metric 0.074535	 valid metric 0.078171
# Epoch 069	 train loss 0.007990	 train metric 0.070985	 valid metric 0.074450
# Epoch 070	 train loss 0.007250	 train metric 0.067606	 valid metric 0.070907
# Epoch 071	 train loss 0.006578	 train metric 0.064387	 valid metric 0.067533
# Epoch 072	 train loss 0.005969	 train metric 0.061323	 valid metric 0.064320
# Epoch 073	 train loss 0.005416	 train metric 0.058406	 valid metric 0.061261
# Epoch 074	 train loss 0.004915	 train metric 0.055628	 valid metric 0.058347
# Epoch 075	 train loss 0.004460	 train metric 0.052983	 valid metric 0.055573
# Epoch 076	 train loss 0.004048	 train metric 0.050464	 valid metric 0.052930
# Epoch 077	 train loss 0.003674	 train metric 0.048065	 valid metric 0.050414
# Epoch 078	 train loss 0.003334	 train metric 0.045782	 valid metric 0.048018
# Epoch 079	 train loss 0.003026	 train metric 0.043608	 valid metric 0.045737
# Epoch 080	 train loss 0.002746	 train metric 0.041538	 valid metric 0.043565
# Epoch 081	 train loss 0.002493	 train metric 0.039567	 valid metric 0.041496
# Epoch 082	 train loss 0.002263	 train metric 0.037690	 valid metric 0.039526
# Epoch 083	 train loss 0.002054	 train metric 0.035902	 valid metric 0.037650
# Epoch 084	 train loss 0.001864	 train metric 0.034199	 valid metric 0.035863
# Epoch 085	 train loss 0.001693	 train metric 0.032578	 valid metric 0.034161
# Epoch 086	 train loss 0.001537	 train metric 0.031034	 valid metric 0.032540
# Epoch 087	 train loss 0.001395	 train metric 0.029563	 valid metric 0.030997
# Epoch 088	 train loss 0.001266	 train metric 0.028162	 valid metric 0.029527
# Epoch 089	 train loss 0.001150	 train metric 0.026829	 valid metric 0.028126
# Epoch 090	 train loss 0.001044	 train metric 0.025558	 valid metric 0.026793
# Epoch 091	 train loss 0.000948	 train metric 0.024349	 valid metric 0.025523
# Epoch 092	 train loss 0.000861	 train metric 0.023196	 valid metric 0.024313
# Epoch 093	 train loss 0.000781	 train metric 0.022099	 valid metric 0.023161
# Epoch 094	 train loss 0.000710	 train metric 0.021054	 valid metric 0.022063
# Epoch 095	 train loss 0.000644	 train metric 0.020058	 valid metric 0.021018
# Epoch 096	 train loss 0.000585	 train metric 0.019110	 valid metric 0.020022
# Epoch 097	 train loss 0.000531	 train metric 0.018207	 valid metric 0.019074
# Epoch 098	 train loss 0.000483	 train metric 0.017347	 valid metric 0.018170
# Epoch 099	 train loss 0.000438	 train metric 0.016527	 valid metric 0.017310
# Test metric 0.016007
# Estimated A
#  [[ 1.7502961   0.39727157]
#  [ 0.9725292   2.2264218 ]
#  [ 1.8526078  -0.97195363]
#  [ 0.94003755 -0.14778529]]
# Estimated b
#  [-0.10920741  0.40893131]

# %% [markdown]
# ## Optimization
#
# Yet this previous code work in _eager_ mode which means that the computation is done in interaction with the CPU iteratively. In order to execute the part of the code that is computation costly on an accelerator, we must put that code into `tf.function` which will enable _graph_ mode.
#
# Look at the two follwing codes, they enable that _graph_ mode.
# The first is directly inspired by the precedent code.
# The second one is using _object oriented programming_ to prevent the use of variables defined outside of a function.
# In the following excercices we will prefer this paradigm.

# %%
# Direct optimization

class LinearRegression(tf.Module):
    def __init__(self, nc, no, name=None):
        super().__init__(name=name)
        # Linear regression parameters
        self.A = tf.Variable(tf.zeros([nc, no]))
        self.b = tf.Variable(tf.zeros([no]))

    @tf.function
    def __call__(self,x):
        return tf.matmul(x, self.A) + self.b


def linear_regression_v1_acc(trainset, validset, testset):

    Xtrain, Ytrain = trainset
    Xvalid, Yvalid = validset
    Xtest, Ytest = testset
    
    # Hyperparameters
    learning_rate = 5e-2
    training_epochs = 100

    # Xtrain (nxtrain,nc)
    nxtrain, nc = Xtrain.shape
    nxtest, _ = Xtest.shape
    # Ytrain (nxtrain,no)
    no = Ytrain.shape[1]

    module = LinearRegression(nc,no)
    
    # We will use the mean square error as loss
    def loss(target,pred):
        return tf.math.reduce_mean(tf.math.squared_difference(target, pred))
        
    # We will use the mean absolute error as metric
    def metric(target,pred):
        return tf.math.reduce_mean(tf.math.abs(target-pred))
    
    # Beware loss and metric are different think.
    # Loss is the differentiable function used for training
    # Metric is a possibly a non-differentiable function use to measure the accuracy.
    
    # Optimizer based on gradient descent
    # It computes gradients of loss over var_list items
    # and construct the updates for var_list items.
    # We don't have to write the gradient step by ourselves
    optimizer = tf.optimizers.SGD(learning_rate=learning_rate)
    
    # We use a separate train_step function that can be autographed
    @tf.function
    def train_step(x,y,xval, yval):
        with tf.GradientTape() as tape:
            trainpred = module(x)
            trainloss = loss(y,trainpred)
        grads = tape.gradient(trainloss,module.trainable_variables)
        trainmetric = metric(y,trainpred)
        
        validpred = module(xval)
        validmetric = metric(yval,validpred)
        
        # Optimizer based on gradient descent
        # We let the optimizer do the gradient descent
        optimizer.apply_gradients(zip(grads, module.trainable_variables))
        return trainloss, trainmetric, validmetric
    
    # As well, we use a separate test_step function that can be autographed
    @tf.function
    def test_step(x,y):
        testpred = module(x)
        testmetric = metric(y,testpred)
        return testmetric

    # We cycle on epochs
    for epoch in range(training_epochs):
        trainloss, trainmetric, validmetric = train_step(Xtrain,Ytrain, Xvalid, Yvalid)
        
        print("Epoch %03d\t train loss %f\t train metric %f\t valid metric %f" %
                  (epoch, trainloss.numpy(), trainmetric.numpy(), validmetric.numpy()))

    testmetric = test_step(Xtest,Ytest)
    print("Test metric %f"%(testmetric.numpy(),))
        
    # Found parameters
    print("Estimated A\n", module.A.numpy())
    print('Estimated b\n', module.b.numpy())

linear_regression_v1_acc(*linear_regression_dataset())
# Out:
# True A
#  [[ 1.76405235  0.40015721]
#  [ 0.97873798  2.2408932 ]
#  [ 1.86755799 -0.97727788]
#  [ 0.95008842 -0.15135721]]
# True b
#  [-0.10321885  0.4105985 ]
# Epoch 000	 train loss 7.184082	 train metric 2.142293	 valid metric 2.241359
# Epoch 001	 train loss 6.501032	 train metric 2.037724	 valid metric 2.131973
# Epoch 002	 train loss 5.883164	 train metric 1.938288	 valid metric 2.028012
# Epoch 003	 train loss 5.324233	 train metric 1.843725	 valid metric 1.929139
# Epoch 004	 train loss 4.818598	 train metric 1.753836	 valid metric 1.835133
# Epoch 005	 train loss 4.361157	 train metric 1.668375	 valid metric 1.745760
# Epoch 006	 train loss 3.947302	 train metric 1.587111	 valid metric 1.660756
# Epoch 007	 train loss 3.572863	 train metric 1.509852	 valid metric 1.579916
# Epoch 008	 train loss 3.234073	 train metric 1.436387	 valid metric 1.503120
# Epoch 009	 train loss 2.927526	 train metric 1.366513	 valid metric 1.430090
# Epoch 010	 train loss 2.650141	 train metric 1.300064	 valid metric 1.360712
# Epoch 011	 train loss 2.399136	 train metric 1.236870	 valid metric 1.294730
# 2021-09-23 11:22:44.336701: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 012	 train loss 2.171991	 train metric 1.176772	 valid metric 1.231959
# Epoch 013	 train loss 1.966431	 train metric 1.119623	 valid metric 1.172243
# Epoch 014	 train loss 1.780396	 train metric 1.065277	 valid metric 1.115433
# Epoch 015	 train loss 1.612025	 train metric 1.013589	 valid metric 1.061404
# Epoch 016	 train loss 1.459636	 train metric 0.964423	 valid metric 1.010026
# Epoch 017	 train loss 1.321705	 train metric 0.917653	 valid metric 0.961144
# Epoch 018	 train loss 1.196856	 train metric 0.873166	 valid metric 0.914636
# Epoch 019	 train loss 1.083843	 train metric 0.830860	 valid metric 0.870387
# Epoch 020	 train loss 0.981541	 train metric 0.790628	 valid metric 0.828287
# Epoch 021	 train loss 0.888930	 train metric 0.752366	 valid metric 0.788231
# Epoch 022	 train loss 0.805089	 train metric 0.715965	 valid metric 0.750118
# Epoch 023	 train loss 0.729184	 train metric 0.681333	 valid metric 0.713856
# Epoch 024	 train loss 0.660462	 train metric 0.648386	 valid metric 0.679353
# Epoch 025	 train loss 0.598241	 train metric 0.617041	 valid metric 0.646523
# Epoch 026	 train loss 0.541902	 train metric 0.587228	 valid metric 0.615286
# Epoch 027	 train loss 0.490889	 train metric 0.558871	 valid metric 0.585564
# Epoch 028	 train loss 0.444695	 train metric 0.531901	 valid metric 0.557282
# Epoch 029	 train loss 0.402864	 train metric 0.506242	 valid metric 0.530372
# Epoch 030	 train loss 0.364982	 train metric 0.481828	 valid metric 0.504766
# Epoch 031	 train loss 0.330675	 train metric 0.458598	 valid metric 0.480400
# Epoch 032	 train loss 0.299605	 train metric 0.436499	 valid metric 0.457215
# Epoch 033	 train loss 0.271465	 train metric 0.415472	 valid metric 0.435167
# Epoch 034	 train loss 0.245977	 train metric 0.395464	 valid metric 0.414212
# Epoch 035	 train loss 0.222891	 train metric 0.376425	 valid metric 0.394281
# Epoch 036	 train loss 0.201979	 train metric 0.358310	 valid metric 0.375327
# Epoch 037	 train loss 0.183037	 train metric 0.341071	 valid metric 0.357287
# Epoch 038	 train loss 0.165877	 train metric 0.324665	 valid metric 0.340117
# Epoch 039	 train loss 0.150332	 train metric 0.309054	 valid metric 0.323775
# Epoch 040	 train loss 0.136249	 train metric 0.294197	 valid metric 0.308222
# Epoch 041	 train loss 0.123490	 train metric 0.280058	 valid metric 0.293418
# Epoch 042	 train loss 0.111930	 train metric 0.266602	 valid metric 0.279328
# Epoch 043	 train loss 0.101456	 train metric 0.253797	 valid metric 0.265918
# Epoch 044	 train loss 0.091966	 train metric 0.241610	 valid metric 0.253161
# Epoch 045	 train loss 0.083366	 train metric 0.230012	 valid metric 0.241019
# Epoch 046	 train loss 0.075574	 train metric 0.218975	 valid metric 0.229461
# Epoch 047	 train loss 0.068512	 train metric 0.208471	 valid metric 0.218459
# Epoch 048	 train loss 0.062113	 train metric 0.198473	 valid metric 0.207997
# Epoch 049	 train loss 0.056314	 train metric 0.188958	 valid metric 0.198040
# Epoch 050	 train loss 0.051057	 train metric 0.179901	 valid metric 0.188565
# Epoch 051	 train loss 0.046294	 train metric 0.171279	 valid metric 0.179544
# Epoch 052	 train loss 0.041976	 train metric 0.163074	 valid metric 0.170957
# Epoch 053	 train loss 0.038062	 train metric 0.155265	 valid metric 0.162781
# Epoch 054	 train loss 0.034515	 train metric 0.147833	 valid metric 0.154998
# Epoch 055	 train loss 0.031299	 train metric 0.140758	 valid metric 0.147588
# Epoch 056	 train loss 0.028384	 train metric 0.134025	 valid metric 0.140534
# Epoch 057	 train loss 0.025742	 train metric 0.127616	 valid metric 0.133820
# Epoch 058	 train loss 0.023346	 train metric 0.121516	 valid metric 0.127430
# Epoch 059	 train loss 0.021174	 train metric 0.115710	 valid metric 0.121346
# Epoch 060	 train loss 0.019205	 train metric 0.110184	 valid metric 0.115554
# Epoch 061	 train loss 0.017419	 train metric 0.104924	 valid metric 0.110039
# Epoch 062	 train loss 0.015800	 train metric 0.099916	 valid metric 0.104788
# Epoch 063	 train loss 0.014332	 train metric 0.095149	 valid metric 0.099789
# Epoch 064	 train loss 0.013001	 train metric 0.090611	 valid metric 0.095029
# Epoch 065	 train loss 0.011794	 train metric 0.086291	 valid metric 0.090497
# Epoch 066	 train loss 0.010700	 train metric 0.082179	 valid metric 0.086184
# Epoch 067	 train loss 0.009707	 train metric 0.078263	 valid metric 0.082079
# Epoch 068	 train loss 0.008807	 train metric 0.074535	 valid metric 0.078171
# Epoch 069	 train loss 0.007990	 train metric 0.070985	 valid metric 0.074450
# Epoch 070	 train loss 0.007250	 train metric 0.067606	 valid metric 0.070907
# Epoch 071	 train loss 0.006578	 train metric 0.064387	 valid metric 0.067533
# Epoch 072	 train loss 0.005969	 train metric 0.061323	 valid metric 0.064320
# Epoch 073	 train loss 0.005416	 train metric 0.058406	 valid metric 0.061261
# Epoch 074	 train loss 0.004915	 train metric 0.055628	 valid metric 0.058347
# Epoch 075	 train loss 0.004460	 train metric 0.052983	 valid metric 0.055573
# Epoch 076	 train loss 0.004048	 train metric 0.050464	 valid metric 0.052930
# Epoch 077	 train loss 0.003674	 train metric 0.048065	 valid metric 0.050414
# Epoch 078	 train loss 0.003334	 train metric 0.045782	 valid metric 0.048018
# Epoch 079	 train loss 0.003026	 train metric 0.043608	 valid metric 0.045737
# Epoch 080	 train loss 0.002746	 train metric 0.041538	 valid metric 0.043565
# Epoch 081	 train loss 0.002493	 train metric 0.039567	 valid metric 0.041496
# Epoch 082	 train loss 0.002263	 train metric 0.037690	 valid metric 0.039526
# Epoch 083	 train loss 0.002054	 train metric 0.035902	 valid metric 0.037650
# Epoch 084	 train loss 0.001864	 train metric 0.034199	 valid metric 0.035863
# Epoch 085	 train loss 0.001693	 train metric 0.032578	 valid metric 0.034161
# Epoch 086	 train loss 0.001537	 train metric 0.031034	 valid metric 0.032540
# Epoch 087	 train loss 0.001395	 train metric 0.029563	 valid metric 0.030997
# Epoch 088	 train loss 0.001266	 train metric 0.028162	 valid metric 0.029527
# Epoch 089	 train loss 0.001150	 train metric 0.026829	 valid metric 0.028126
# Epoch 090	 train loss 0.001044	 train metric 0.025558	 valid metric 0.026793
# Epoch 091	 train loss 0.000948	 train metric 0.024349	 valid metric 0.025523
# Epoch 092	 train loss 0.000861	 train metric 0.023196	 valid metric 0.024313
# Epoch 093	 train loss 0.000781	 train metric 0.022099	 valid metric 0.023161
# Epoch 094	 train loss 0.000710	 train metric 0.021054	 valid metric 0.022063
# Epoch 095	 train loss 0.000644	 train metric 0.020058	 valid metric 0.021018
# Epoch 096	 train loss 0.000585	 train metric 0.019110	 valid metric 0.020022
# Epoch 097	 train loss 0.000531	 train metric 0.018207	 valid metric 0.019074
# Epoch 098	 train loss 0.000483	 train metric 0.017347	 valid metric 0.018170
# Epoch 099	 train loss 0.000438	 train metric 0.016527	 valid metric 0.017310
# Test metric 0.016007
# Estimated A
#  [[ 1.7502961   0.39727157]
#  [ 0.9725292   2.2264218 ]
#  [ 1.8526078  -0.97195363]
#  [ 0.94003755 -0.14778529]]
# Estimated b
#  [-0.10920741  0.40893131]
# 2021-09-23 11:22:44.801015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
# Optimization inside a Trainer class

class LinearRegression(tf.Module):
    def __init__(self, nc, no, name=None):
        super().__init__(name=name)
        # Linear regression parameters
        self.A = tf.Variable(tf.zeros([nc, no]))
        self.b = tf.Variable(tf.zeros([no]))

    @tf.function
    def __call__(self,x):
        return tf.matmul(x, self.A) + self.b

class LinearRegressionTrainer:
    
    # We will use the MSE loss
    def _loss(self,target,pred):
        return tf.reduce_mean(tf.math.squared_difference(target, pred))

    # We will use the mean absolute error as metric
    def _metric(self,target,pred):
        return tf.math.reduce_mean(tf.math.abs(target-pred))        

    # We use a separate train_step method that can be autographed
    @tf.function
    def _train_step(self,x,y,xval,yval):
        with tf.GradientTape() as tape:
            trainpred = self.module(x)
            trainloss = self._loss(y,trainpred)
        grads = tape.gradient(trainloss,self.module.trainable_variables)
        trainmetric = self._metric(y,trainpred)

        validpred = self.module(xval)
        validmetric = self._metric(yval,validpred)

        # Optimizer based on gradient descent
        # We let the optimizer do the gradient descent
        self.optimizer.apply_gradients(zip(grads, self.module.trainable_variables))
        return trainloss, trainmetric, validmetric

    # As well, we use a separate test_step method that can be autographed
    @tf.function
    def _test_step(self,x,y):
        testpred = self.module(x)
        testmetric = self._metric(y,testpred)
        return testmetric

    def train(self, trainset, validset, testset,
            learning_rate = 5e-2, training_epochs = 100):

        Xtrain, Ytrain = trainset
        Xvalid, Yvalid = validset
        Xtest, Ytest = testset
        
        # Xtrain (nxtrain,nc)
        nxtrain, self.nc = Xtrain.shape
        nxtest, _ = Xtest.shape
        # Ytrain (nxtrain,no)
        self.no = Ytrain.shape[1]
        
        self.module = LinearRegression(self.nc,self.no)
        self.optimizer = tf.optimizers.SGD(learning_rate=learning_rate)
        
        # We cycle on epochs
        for epoch in range(training_epochs):
            trainloss, trainmetric, validmetric = self._train_step(Xtrain,Ytrain,Xvalid, Yvalid)

            print("Epoch %03d\t train loss %f\t train metric %f\t valid metric %f" %
                      (epoch, trainloss.numpy(), trainmetric.numpy(), validmetric.numpy()))

        testmetric = self._test_step(Xtest,Ytest)
        print("Test metric %f"%(testmetric.numpy(),))

        # Found parameters
        print("Estimated A\n", self.module.A.numpy())
        print('Estimated b\n', self.module.b.numpy())

trainer = LinearRegressionTrainer()
trainer.train(*linear_regression_dataset())
# Out:
# 2021-09-23 11:22:44.908867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# True A
#  [[ 1.76405235  0.40015721]
#  [ 0.97873798  2.2408932 ]
#  [ 1.86755799 -0.97727788]
#  [ 0.95008842 -0.15135721]]
# True b
#  [-0.10321885  0.4105985 ]
# Epoch 000	 train loss 7.184082	 train metric 2.142293	 valid metric 2.241359
# Epoch 001	 train loss 6.501032	 train metric 2.037724	 valid metric 2.131973
# Epoch 002	 train loss 5.883164	 train metric 1.938288	 valid metric 2.028012
# Epoch 003	 train loss 5.324233	 train metric 1.843725	 valid metric 1.929139
# Epoch 004	 train loss 4.818598	 train metric 1.753836	 valid metric 1.835133
# Epoch 005	 train loss 4.361157	 train metric 1.668375	 valid metric 1.745760
# Epoch 006	 train loss 3.947302	 train metric 1.587111	 valid metric 1.660756
# Epoch 007	 train loss 3.572863	 train metric 1.509852	 valid metric 1.579916
# Epoch 008	 train loss 3.234073	 train metric 1.436387	 valid metric 1.503120
# Epoch 009	 train loss 2.927526	 train metric 1.366513	 valid metric 1.430090
# Epoch 010	 train loss 2.650141	 train metric 1.300064	 valid metric 1.360712
# Epoch 011	 train loss 2.399136	 train metric 1.236870	 valid metric 1.294730
# Epoch 012	 train loss 2.171991	 train metric 1.176772	 valid metric 1.231959
# Epoch 013	 train loss 1.966431	 train metric 1.119623	 valid metric 1.172243
# Epoch 014	 train loss 1.780396	 train metric 1.065277	 valid metric 1.115433
# Epoch 015	 train loss 1.612025	 train metric 1.013589	 valid metric 1.061404
# Epoch 016	 train loss 1.459636	 train metric 0.964423	 valid metric 1.010026
# Epoch 017	 train loss 1.321705	 train metric 0.917653	 valid metric 0.961144
# Epoch 018	 train loss 1.196856	 train metric 0.873166	 valid metric 0.914636
# Epoch 019	 train loss 1.083843	 train metric 0.830860	 valid metric 0.870387
# Epoch 020	 train loss 0.981541	 train metric 0.790628	 valid metric 0.828287
# Epoch 021	 train loss 0.888930	 train metric 0.752366	 valid metric 0.788231
# Epoch 022	 train loss 0.805089	 train metric 0.715965	 valid metric 0.750118
# Epoch 023	 train loss 0.729184	 train metric 0.681333	 valid metric 0.713856
# Epoch 024	 train loss 0.660462	 train metric 0.648386	 valid metric 0.679353
# Epoch 025	 train loss 0.598241	 train metric 0.617041	 valid metric 0.646523
# Epoch 026	 train loss 0.541902	 train metric 0.587228	 valid metric 0.615286
# Epoch 027	 train loss 0.490889	 train metric 0.558871	 valid metric 0.585564
# Epoch 028	 train loss 0.444695	 train metric 0.531901	 valid metric 0.557282
# Epoch 029	 train loss 0.402864	 train metric 0.506242	 valid metric 0.530372
# Epoch 030	 train loss 0.364982	 train metric 0.481828	 valid metric 0.504766
# Epoch 031	 train loss 0.330675	 train metric 0.458598	 valid metric 0.480400
# Epoch 032	 train loss 0.299605	 train metric 0.436499	 valid metric 0.457215
# Epoch 033	 train loss 0.271465	 train metric 0.415472	 valid metric 0.435167
# Epoch 034	 train loss 0.245977	 train metric 0.395464	 valid metric 0.414212
# Epoch 035	 train loss 0.222891	 train metric 0.376425	 valid metric 0.394281
# Epoch 036	 train loss 0.201979	 train metric 0.358310	 valid metric 0.375327
# Epoch 037	 train loss 0.183037	 train metric 0.341071	 valid metric 0.357287
# Epoch 038	 train loss 0.165877	 train metric 0.324665	 valid metric 0.340117
# Epoch 039	 train loss 0.150332	 train metric 0.309054	 valid metric 0.323775
# Epoch 040	 train loss 0.136249	 train metric 0.294197	 valid metric 0.308222
# Epoch 041	 train loss 0.123490	 train metric 0.280058	 valid metric 0.293418
# Epoch 042	 train loss 0.111930	 train metric 0.266602	 valid metric 0.279328
# Epoch 043	 train loss 0.101456	 train metric 0.253797	 valid metric 0.265918
# Epoch 044	 train loss 0.091966	 train metric 0.241610	 valid metric 0.253161
# Epoch 045	 train loss 0.083366	 train metric 0.230012	 valid metric 0.241019
# Epoch 046	 train loss 0.075574	 train metric 0.218975	 valid metric 0.229461
# Epoch 047	 train loss 0.068512	 train metric 0.208471	 valid metric 0.218459
# Epoch 048	 train loss 0.062113	 train metric 0.198473	 valid metric 0.207997
# Epoch 049	 train loss 0.056314	 train metric 0.188958	 valid metric 0.198040
# Epoch 050	 train loss 0.051057	 train metric 0.179901	 valid metric 0.188565
# Epoch 051	 train loss 0.046294	 train metric 0.171279	 valid metric 0.179544
# Epoch 052	 train loss 0.041976	 train metric 0.163074	 valid metric 0.170957
# Epoch 053	 train loss 0.038062	 train metric 0.155265	 valid metric 0.162781
# Epoch 054	 train loss 0.034515	 train metric 0.147833	 valid metric 0.154998
# Epoch 055	 train loss 0.031299	 train metric 0.140758	 valid metric 0.147588
# Epoch 056	 train loss 0.028384	 train metric 0.134025	 valid metric 0.140534
# Epoch 057	 train loss 0.025742	 train metric 0.127616	 valid metric 0.133820
# Epoch 058	 train loss 0.023346	 train metric 0.121516	 valid metric 0.127430
# Epoch 059	 train loss 0.021174	 train metric 0.115710	 valid metric 0.121346
# Epoch 060	 train loss 0.019205	 train metric 0.110184	 valid metric 0.115554
# Epoch 061	 train loss 0.017419	 train metric 0.104924	 valid metric 0.110039
# Epoch 062	 train loss 0.015800	 train metric 0.099916	 valid metric 0.104788
# Epoch 063	 train loss 0.014332	 train metric 0.095149	 valid metric 0.099789
# Epoch 064	 train loss 0.013001	 train metric 0.090611	 valid metric 0.095029
# Epoch 065	 train loss 0.011794	 train metric 0.086291	 valid metric 0.090497
# Epoch 066	 train loss 0.010700	 train metric 0.082179	 valid metric 0.086184
# Epoch 067	 train loss 0.009707	 train metric 0.078263	 valid metric 0.082079
# Epoch 068	 train loss 0.008807	 train metric 0.074535	 valid metric 0.078171
# Epoch 069	 train loss 0.007990	 train metric 0.070985	 valid metric 0.074450
# Epoch 070	 train loss 0.007250	 train metric 0.067606	 valid metric 0.070907
# Epoch 071	 train loss 0.006578	 train metric 0.064387	 valid metric 0.067533
# Epoch 072	 train loss 0.005969	 train metric 0.061323	 valid metric 0.064320
# Epoch 073	 train loss 0.005416	 train metric 0.058406	 valid metric 0.061261
# Epoch 074	 train loss 0.004915	 train metric 0.055628	 valid metric 0.058347
# Epoch 075	 train loss 0.004460	 train metric 0.052983	 valid metric 0.055573
# Epoch 076	 train loss 0.004048	 train metric 0.050464	 valid metric 0.052930
# Epoch 077	 train loss 0.003674	 train metric 0.048065	 valid metric 0.050414
# Epoch 078	 train loss 0.003334	 train metric 0.045782	 valid metric 0.048018
# Epoch 079	 train loss 0.003026	 train metric 0.043608	 valid metric 0.045737
# Epoch 080	 train loss 0.002746	 train metric 0.041538	 valid metric 0.043565
# Epoch 081	 train loss 0.002493	 train metric 0.039567	 valid metric 0.041496
# Epoch 082	 train loss 0.002263	 train metric 0.037690	 valid metric 0.039526
# Epoch 083	 train loss 0.002054	 train metric 0.035902	 valid metric 0.037650
# Epoch 084	 train loss 0.001864	 train metric 0.034199	 valid metric 0.035863
# Epoch 085	 train loss 0.001693	 train metric 0.032578	 valid metric 0.034161
# Epoch 086	 train loss 0.001537	 train metric 0.031034	 valid metric 0.032540
# Epoch 087	 train loss 0.001395	 train metric 0.029563	 valid metric 0.030997
# Epoch 088	 train loss 0.001266	 train metric 0.028162	 valid metric 0.029527
# Epoch 089	 train loss 0.001150	 train metric 0.026829	 valid metric 0.028126
# Epoch 090	 train loss 0.001044	 train metric 0.025558	 valid metric 0.026793
# Epoch 091	 train loss 0.000948	 train metric 0.024349	 valid metric 0.025523
# Epoch 092	 train loss 0.000861	 train metric 0.023196	 valid metric 0.024313
# Epoch 093	 train loss 0.000781	 train metric 0.022099	 valid metric 0.023161
# Epoch 094	 train loss 0.000710	 train metric 0.021054	 valid metric 0.022063
# Epoch 095	 train loss 0.000644	 train metric 0.020058	 valid metric 0.021018
# Epoch 096	 train loss 0.000585	 train metric 0.019110	 valid metric 0.020022
# Epoch 097	 train loss 0.000531	 train metric 0.018207	 valid metric 0.019074
# Epoch 098	 train loss 0.000483	 train metric 0.017347	 valid metric 0.018170
# Epoch 099	 train loss 0.000438	 train metric 0.016527	 valid metric 0.017310
# Test metric 0.016007
# Estimated A
#  [[ 1.7502961   0.39727157]
#  [ 0.9725292   2.2264218 ]
#  [ 1.8526078  -0.97195363]
#  [ 0.94003755 -0.14778529]]
# Estimated b
#  [-0.10920741  0.40893131]
# 2021-09-23 11:22:45.356739: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Dataset
#
# In the precedent example, all the dataset is used at each gradient step.
# In most of the case, you can't do that as it will not fit into the memory of the computation engine.
# You have to split your data into little batches. Tensorflow dataset are here to help you in that process.
#
# Let's observe the next script.
# It presents how to create a Tensorflow dataset object and how to create bacthes to iterate over it.
# For each batch, the content of the bacth is displayed as well as the computation of a phony operation.

# %%
def play_with_tensorflow_dataset_v1():
    # create fake data

    nsamples = 105

    X = np.arange(nsamples, dtype='float32').reshape(nsamples, 1)
    Y = np.zeros((nsamples, 1), dtype='float32')
    Y[:int(np.ceil(nsamples/2))]=1.
    
    # loop / batch parameters
    nepochs = 5
    batchsize = 8
    
    # Create a dataset from numpy array
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    # Uncomment following line if you want to automatically shuffe the dataset
    #dataset = dataset.shuffle(buffer_size=1000)
    # Each iteration over the dataset will provide batchsize samples
    dataset = dataset.batch(batchsize)
    # or if you want to drop the last non complete batch
    #dataset = dataset.batch(batchsize, drop_remainder=True)

    # Loop over epochs
    for epoch in range(nepochs):
        print('Epoch %d'%(epoch,))
        # Loop over batches
        for batch, (xbatch, ybatch)  in enumerate(dataset):
            print("Epoch %d Batch %d"%(epoch,batch),"\nx", xbatch,"\ny",ybatch)


play_with_tensorflow_dataset_v1()
# Out:
# Epoch 0
# Epoch 0 Batch 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 0 Batch 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# Epoch 1
# Epoch 1 Batch 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 1 Batch 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# Epoch 2
# Epoch 2 Batch 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 2 Batch 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# Epoch 3
# Epoch 3 Batch 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 3 Batch 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# Epoch 4
# Epoch 4 Batch 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# Epoch 4 Batch 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[0.]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ## Multiple dataset and metrics
#
# What should we do with multiple dataset ? For example how can we iterate over train and validation ?
#
# Moreover, how can we compute a metrics over batches ?
#
# Take a look at the following code which use `tensorflow.metrics` tools.
#
# Please note that it is a fake example without actual training.

# %%
def play_with_tensorflow_dataset_v2():

    # create fake data
    nsamples = 105

    Xtrain = np.arange(nsamples, dtype='float32').reshape(nsamples, 1)
    Ytrain = np.ones((nsamples, 1), dtype='float32')

    Xvalid = np.arange(nsamples, dtype='float32').reshape(nsamples, 1)[::-1]
    Yvalid = -np.ones((nsamples, 1), dtype='float32')

    # loop / batch parameters
    nepochs = 5
    batchsize = 8
    
    # Create a dataset from numpy array
    traindataset = tf.data.Dataset.from_tensor_slices((Xtrain, Ytrain))
    # Uncomment following line if you want to automatically shuffe the dataset
    #traindataset = traindataset.shuffle(buffer_size=1000)
    # Each iteration over the dataset will provide batchsize samples
    traindataset = traindataset.batch(batchsize)
    # or if you want to drop the last non complete batch
    #traindataset = traindataset.batch(batchsize, drop_remainder=True)
    
    # Create a dataset from numpy array
    validdataset = tf.data.Dataset.from_tensor_slices((Xvalid, Yvalid))
    # Uncomment following line if you want to automatically shuffe the dataset
    #validdataset = validdataset.shuffle(buffer_size=1000)
    # Each iteration over the dataset will provide batchsize samples
    validdataset = validdataset.batch(batchsize)
    # or if you want to drop the last non complete batch
    #validdataset = validdataset.batch(batchsize, drop_remainder=True)
    
    # We instanciate a metric for the train and another for the validation
    trainmse = tf.metrics.MeanAbsoluteError()
    validmse = tf.metrics.MeanAbsoluteError()
    
    # Loop over epochs
    for epoch in range(nepochs):
        
        # At the beggining of each epoch, metrics must be reset:
        trainmse.reset_state()
        # Loop over train batches
        for batch, (xbatch, ybatch)  in enumerate(traindataset):
            print("Epoch %d Train Bacth %d"%(epoch,batch),"\nx", xbatch,"\ny",ybatch)
            ypred= xbatch
            #the new batch result is sent to the metric
            trainmse.update_state(ybatch,ypred)
        # At the end we can retrieve the metrics over all the batches
        print("Epoch %d Train Metric %f"%(epoch,trainmse.result()))
        
        # At the beggining of each epoch, metrics must be reset:
        validmse.reset_state()    
        # Loop over valid batches
        for batch, (xbatch, ybatch)  in enumerate(validdataset):
            print("Epoch %d Valid Bacth %d"%(epoch,batch),"\nx", xbatch,"\ny",ybatch)
            ypred= xbatch
            #the new batch result is sent to the metric
            validmse.update_state(ybatch,ypred)
        # At the end we can retrieve the metrics over all the batches
        print("Epoch %d Valid Metric %f"%(epoch,validmse.result()))
                                  
play_with_tensorflow_dataset_v2()
# Out:
# Epoch 0 Train Bacth 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Train Bacth 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[1.]], shape=(1, 1), dtype=float32)
# Epoch 0 Train Metric 51.019051
# Epoch 0 Valid Bacth 0
# x tf.Tensor(
# [[104.]
#  [103.]
#  [102.]
#  [101.]
#  [100.]
#  [ 99.]
#  [ 98.]
#  [ 97.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 1
# x tf.Tensor(
# [[96.]
#  [95.]
#  [94.]
#  [93.]
#  [92.]
#  [91.]
#  [90.]
#  [89.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 2
# x tf.Tensor(
# [[88.]
#  [87.]
#  [86.]
#  [85.]
#  [84.]
#  [83.]
#  [82.]
#  [81.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 3
# x tf.Tensor(
# [[80.]
#  [79.]
#  [78.]
#  [77.]
#  [76.]
#  [75.]
#  [74.]
#  [73.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 4
# x tf.Tensor(
# [[72.]
#  [71.]
#  [70.]
#  [69.]
#  [68.]
#  [67.]
#  [66.]
#  [65.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 5
# x tf.Tensor(
# [[64.]
#  [63.]
#  [62.]
#  [61.]
#  [60.]
#  [59.]
#  [58.]
#  [57.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 6
# x tf.Tensor(
# [[56.]
#  [55.]
#  [54.]
#  [53.]
#  [52.]
#  [51.]
#  [50.]
#  [49.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 7
# x tf.Tensor(
# [[48.]
#  [47.]
#  [46.]
#  [45.]
#  [44.]
#  [43.]
#  [42.]
#  [41.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 8
# x tf.Tensor(
# [[40.]
#  [39.]
#  [38.]
#  [37.]
#  [36.]
#  [35.]
#  [34.]
#  [33.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 9
# x tf.Tensor(
# [[32.]
#  [31.]
#  [30.]
#  [29.]
#  [28.]
#  [27.]
#  [26.]
#  [25.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 10
# x tf.Tensor(
# [[24.]
#  [23.]
#  [22.]
#  [21.]
#  [20.]
#  [19.]
#  [18.]
#  [17.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 11
# x tf.Tensor(
# [[16.]
#  [15.]
#  [14.]
#  [13.]
#  [12.]
#  [11.]
#  [10.]
#  [ 9.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 12
# x tf.Tensor(
# [[8.]
#  [7.]
#  [6.]
#  [5.]
#  [4.]
#  [3.]
#  [2.]
#  [1.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 0 Valid Bacth 13
# x tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[-1.]], shape=(1, 1), dtype=float32)
# Epoch 0 Valid Metric 53.000004
# Epoch 1 Train Bacth 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Train Bacth 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[1.]], shape=(1, 1), dtype=float32)
# Epoch 1 Train Metric 51.019051
# Epoch 1 Valid Bacth 0
# x tf.Tensor(
# [[104.]
#  [103.]
#  [102.]
#  [101.]
#  [100.]
#  [ 99.]
#  [ 98.]
#  [ 97.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 1
# x tf.Tensor(
# [[96.]
#  [95.]
#  [94.]
#  [93.]
#  [92.]
#  [91.]
#  [90.]
#  [89.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 2
# x tf.Tensor(
# [[88.]
#  [87.]
#  [86.]
#  [85.]
#  [84.]
#  [83.]
#  [82.]
#  [81.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 3
# x tf.Tensor(
# [[80.]
#  [79.]
#  [78.]
#  [77.]
#  [76.]
#  [75.]
#  [74.]
#  [73.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 4
# x tf.Tensor(
# [[72.]
#  [71.]
#  [70.]
#  [69.]
#  [68.]
#  [67.]
#  [66.]
#  [65.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 5
# x tf.Tensor(
# [[64.]
#  [63.]
#  [62.]
#  [61.]
#  [60.]
#  [59.]
#  [58.]
#  [57.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 6
# x tf.Tensor(
# [[56.]
#  [55.]
#  [54.]
#  [53.]
#  [52.]
#  [51.]
#  [50.]
#  [49.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 7
# x tf.Tensor(
# [[48.]
#  [47.]
#  [46.]
#  [45.]
#  [44.]
#  [43.]
#  [42.]
#  [41.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 8
# x tf.Tensor(
# [[40.]
#  [39.]
#  [38.]
#  [37.]
#  [36.]
#  [35.]
#  [34.]
#  [33.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 9
# x tf.Tensor(
# [[32.]
#  [31.]
#  [30.]
#  [29.]
#  [28.]
#  [27.]
#  [26.]
#  [25.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 10
# x tf.Tensor(
# [[24.]
#  [23.]
#  [22.]
#  [21.]
#  [20.]
#  [19.]
#  [18.]
#  [17.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 11
# x tf.Tensor(
# [[16.]
#  [15.]
#  [14.]
#  [13.]
#  [12.]
#  [11.]
#  [10.]
#  [ 9.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 12
# x tf.Tensor(
# [[8.]
#  [7.]
#  [6.]
#  [5.]
#  [4.]
#  [3.]
#  [2.]
#  [1.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 1 Valid Bacth 13
# x tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[-1.]], shape=(1, 1), dtype=float32)
# Epoch 1 Valid Metric 53.000004
# Epoch 2 Train Bacth 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Train Bacth 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[1.]], shape=(1, 1), dtype=float32)
# Epoch 2 Train Metric 51.019051
# Epoch 2 Valid Bacth 0
# x tf.Tensor(
# [[104.]
#  [103.]
#  [102.]
#  [101.]
#  [100.]
#  [ 99.]
#  [ 98.]
#  [ 97.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 1
# x tf.Tensor(
# [[96.]
#  [95.]
#  [94.]
#  [93.]
#  [92.]
#  [91.]
#  [90.]
#  [89.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 2
# x tf.Tensor(
# [[88.]
#  [87.]
#  [86.]
#  [85.]
#  [84.]
#  [83.]
#  [82.]
#  [81.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 3
# x tf.Tensor(
# [[80.]
#  [79.]
#  [78.]
#  [77.]
#  [76.]
#  [75.]
#  [74.]
#  [73.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 4
# x tf.Tensor(
# [[72.]
#  [71.]
#  [70.]
#  [69.]
#  [68.]
#  [67.]
#  [66.]
#  [65.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 5
# x tf.Tensor(
# [[64.]
#  [63.]
#  [62.]
#  [61.]
#  [60.]
#  [59.]
#  [58.]
#  [57.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 6
# x tf.Tensor(
# [[56.]
#  [55.]
#  [54.]
#  [53.]
#  [52.]
#  [51.]
#  [50.]
#  [49.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 7
# x tf.Tensor(
# [[48.]
#  [47.]
#  [46.]
#  [45.]
#  [44.]
#  [43.]
#  [42.]
#  [41.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 8
# x tf.Tensor(
# [[40.]
#  [39.]
#  [38.]
#  [37.]
#  [36.]
#  [35.]
#  [34.]
#  [33.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 9
# x tf.Tensor(
# [[32.]
#  [31.]
#  [30.]
#  [29.]
#  [28.]
#  [27.]
#  [26.]
#  [25.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 10
# x tf.Tensor(
# [[24.]
#  [23.]
#  [22.]
#  [21.]
#  [20.]
#  [19.]
#  [18.]
#  [17.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 11
# x tf.Tensor(
# [[16.]
#  [15.]
#  [14.]
#  [13.]
#  [12.]
#  [11.]
#  [10.]
#  [ 9.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 12
# x tf.Tensor(
# [[8.]
#  [7.]
#  [6.]
#  [5.]
#  [4.]
#  [3.]
#  [2.]
#  [1.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 2 Valid Bacth 13
# x tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[-1.]], shape=(1, 1), dtype=float32)
# Epoch 2 Valid Metric 53.000004
# Epoch 3 Train Bacth 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Train Bacth 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[1.]], shape=(1, 1), dtype=float32)
# Epoch 3 Train Metric 51.019051
# Epoch 3 Valid Bacth 0
# x tf.Tensor(
# [[104.]
#  [103.]
#  [102.]
#  [101.]
#  [100.]
#  [ 99.]
#  [ 98.]
#  [ 97.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 1
# x tf.Tensor(
# [[96.]
#  [95.]
#  [94.]
#  [93.]
#  [92.]
#  [91.]
#  [90.]
#  [89.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 2
# x tf.Tensor(
# [[88.]
#  [87.]
#  [86.]
#  [85.]
#  [84.]
#  [83.]
#  [82.]
#  [81.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 3
# x tf.Tensor(
# [[80.]
#  [79.]
#  [78.]
#  [77.]
#  [76.]
#  [75.]
#  [74.]
#  [73.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 4
# x tf.Tensor(
# [[72.]
#  [71.]
#  [70.]
#  [69.]
#  [68.]
#  [67.]
#  [66.]
#  [65.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 5
# x tf.Tensor(
# [[64.]
#  [63.]
#  [62.]
#  [61.]
#  [60.]
#  [59.]
#  [58.]
#  [57.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 6
# x tf.Tensor(
# [[56.]
#  [55.]
#  [54.]
#  [53.]
#  [52.]
#  [51.]
#  [50.]
#  [49.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 7
# x tf.Tensor(
# [[48.]
#  [47.]
#  [46.]
#  [45.]
#  [44.]
#  [43.]
#  [42.]
#  [41.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 8
# x tf.Tensor(
# [[40.]
#  [39.]
#  [38.]
#  [37.]
#  [36.]
#  [35.]
#  [34.]
#  [33.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 9
# x tf.Tensor(
# [[32.]
#  [31.]
#  [30.]
#  [29.]
#  [28.]
#  [27.]
#  [26.]
#  [25.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 10
# x tf.Tensor(
# [[24.]
#  [23.]
#  [22.]
#  [21.]
#  [20.]
#  [19.]
#  [18.]
#  [17.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 11
# x tf.Tensor(
# [[16.]
#  [15.]
#  [14.]
#  [13.]
#  [12.]
#  [11.]
#  [10.]
#  [ 9.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 12
# x tf.Tensor(
# [[8.]
#  [7.]
#  [6.]
#  [5.]
#  [4.]
#  [3.]
#  [2.]
#  [1.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 3 Valid Bacth 13
# x tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[-1.]], shape=(1, 1), dtype=float32)
# Epoch 3 Valid Metric 53.000004
# Epoch 4 Train Bacth 0
# x tf.Tensor(
# [[0.]
#  [1.]
#  [2.]
#  [3.]
#  [4.]
#  [5.]
#  [6.]
#  [7.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 1
# x tf.Tensor(
# [[ 8.]
#  [ 9.]
#  [10.]
#  [11.]
#  [12.]
#  [13.]
#  [14.]
#  [15.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 2
# x tf.Tensor(
# [[16.]
#  [17.]
#  [18.]
#  [19.]
#  [20.]
#  [21.]
#  [22.]
#  [23.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 3
# x tf.Tensor(
# [[24.]
#  [25.]
#  [26.]
#  [27.]
#  [28.]
#  [29.]
#  [30.]
#  [31.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 4
# x tf.Tensor(
# [[32.]
#  [33.]
#  [34.]
#  [35.]
#  [36.]
#  [37.]
#  [38.]
#  [39.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 5
# x tf.Tensor(
# [[40.]
#  [41.]
#  [42.]
#  [43.]
#  [44.]
#  [45.]
#  [46.]
#  [47.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 6
# x tf.Tensor(
# [[48.]
#  [49.]
#  [50.]
#  [51.]
#  [52.]
#  [53.]
#  [54.]
#  [55.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 7
# x tf.Tensor(
# [[56.]
#  [57.]
#  [58.]
#  [59.]
#  [60.]
#  [61.]
#  [62.]
#  [63.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 8
# x tf.Tensor(
# [[64.]
#  [65.]
#  [66.]
#  [67.]
#  [68.]
#  [69.]
#  [70.]
#  [71.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 9
# x tf.Tensor(
# [[72.]
#  [73.]
#  [74.]
#  [75.]
#  [76.]
#  [77.]
#  [78.]
#  [79.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 10
# x tf.Tensor(
# [[80.]
#  [81.]
#  [82.]
#  [83.]
#  [84.]
#  [85.]
#  [86.]
#  [87.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 11
# x tf.Tensor(
# [[88.]
#  [89.]
#  [90.]
#  [91.]
#  [92.]
#  [93.]
#  [94.]
#  [95.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 12
# x tf.Tensor(
# [[ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Train Bacth 13
# x tf.Tensor([[104.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[1.]], shape=(1, 1), dtype=float32)
# Epoch 4 Train Metric 51.019051
# Epoch 4 Valid Bacth 0
# x tf.Tensor(
# [[104.]
#  [103.]
#  [102.]
#  [101.]
#  [100.]
#  [ 99.]
#  [ 98.]
#  [ 97.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 1
# x tf.Tensor(
# [[96.]
#  [95.]
#  [94.]
#  [93.]
#  [92.]
#  [91.]
#  [90.]
#  [89.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 2
# x tf.Tensor(
# [[88.]
#  [87.]
#  [86.]
#  [85.]
#  [84.]
#  [83.]
#  [82.]
#  [81.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 3
# x tf.Tensor(
# [[80.]
#  [79.]
#  [78.]
#  [77.]
#  [76.]
#  [75.]
#  [74.]
#  [73.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 4
# x tf.Tensor(
# [[72.]
#  [71.]
#  [70.]
#  [69.]
#  [68.]
#  [67.]
#  [66.]
#  [65.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 5
# x tf.Tensor(
# [[64.]
#  [63.]
#  [62.]
#  [61.]
#  [60.]
#  [59.]
#  [58.]
#  [57.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 6
# x tf.Tensor(
# [[56.]
#  [55.]
#  [54.]
#  [53.]
#  [52.]
#  [51.]
#  [50.]
#  [49.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 7
# x tf.Tensor(
# [[48.]
#  [47.]
#  [46.]
#  [45.]
#  [44.]
#  [43.]
#  [42.]
#  [41.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 8
# x tf.Tensor(
# [[40.]
#  [39.]
#  [38.]
#  [37.]
#  [36.]
#  [35.]
#  [34.]
#  [33.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 9
# x tf.Tensor(
# [[32.]
#  [31.]
#  [30.]
#  [29.]
#  [28.]
#  [27.]
#  [26.]
#  [25.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 10
# x tf.Tensor(
# [[24.]
#  [23.]
#  [22.]
#  [21.]
#  [20.]
#  [19.]
#  [18.]
#  [17.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 11
# x tf.Tensor(
# [[16.]
#  [15.]
#  [14.]
#  [13.]
#  [12.]
#  [11.]
#  [10.]
#  [ 9.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 12
# x tf.Tensor(
# [[8.]
#  [7.]
#  [6.]
#  [5.]
#  [4.]
#  [3.]
#  [2.]
#  [1.]], shape=(8, 1), dtype=float32)
# y tf.Tensor(
# [[-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]
#  [-1.]], shape=(8, 1), dtype=float32)
# Epoch 4 Valid Bacth 13
# x tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# y tf.Tensor([[-1.]], shape=(1, 1), dtype=float32)
# Epoch 4 Valid Metric 53.000004

# %% [markdown]
# ## Your turn !
#
# Modify the initial linear regression function to introduce mini batches.
